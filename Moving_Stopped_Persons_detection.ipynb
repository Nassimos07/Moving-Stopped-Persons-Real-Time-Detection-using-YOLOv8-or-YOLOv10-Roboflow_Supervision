# %% [markdown]
# # $Analysing$ $Human$ $Movement$ $Patterns$ $in$ $Diverse$ $Environments$ $using$ *``YOLOv8 \ YOLOv10``*  $\&$  *``Roboflow Supervision``*
#
# ---
#
# <a align="">
#   <img width="1200"src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png">
# </a>
#
# <a align="">

# %% [markdown]
# # $Setup$ ✅
# ---

# %%
import cv2
import os
import shutil
import numpy as np
import yaml
import torch

# %%
# Check for CUDA device and set it
torch.cuda.set_device(0)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')
  # checks
# Out:
# Using device: cuda

# %%
from ultralytics import YOLO, checks, hub
checks()
# Out:
# Ultralytics YOLOv8.2.72  Python-3.10.8 torch-2.3.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650 Ti with Max-Q Design, 4096MiB)
# Setup complete  (12 CPUs, 15.8 GB RAM, 311.0/337.3 GB disk)

# %% [markdown]
# ###  $Supervision$
#
# <a align="center">
#   <img width ="1200" src="https://camo.githubusercontent.">
# </a>

# %%
import supervision as sv

# %%
import supervision as sv
from supervision.draw.color import ColorPalette
from supervision import Detections, BoxAnnotator
smoother = sv.DetectionsSmoother()

# %% [markdown]
# # $Model$ $Selection$ 🍇
# ---

# %% [markdown]
# ### $YOLOv8x$ $model$

# %%
from ultralytics import YOLO
model = YOLO("yolov8x.pt").to(device)  # load a pretrained model (recommended for training)

# %% [markdown]
# ### $YOLOv8n$ $model$

# %%
model = YOLO("yolov8n.pt").to(device)  # load a pretrained model (recommended for training)

# %% [markdown]
# # $Movement$ $Analysis$ 🏃🏻‍♀️
# ---

# %% [markdown]
#  The Input Video: *the video that we will test it*

# %%
SOURCE_VIDEO_PATH=r'C:\Users\MSI\Desktop\Upwork Projects\2. Computer Vision and Image Processing\Oussema Project (Aerport Object Detection, Persons Counting, Mouvement Analysis)\Videos\videos\Test\test1.mp4'   #  Change the path
video_info = sv.VideoInfo.from_video_path(video_path=SOURCE_VIDEO_PATH)
video_info
# Out:
# VideoInfo(width=1920, height=1080, fps=25, total_frames=341)

# %% [markdown]
# Utils

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - car, motorcycle, bus and truck
CLASS_ID = [i for i in range(80)]

# %%
def get_bbox_center(box):
    """Calculate the center point coordinates of a bounding box.

    Args:
        box (numpy.ndarray): A numpy array containing the bounding box coordinates in the form (xmin, ymin, xmax, ymax).

    Returns:
        tuple: A tuple containing the coordinates of the center point in the form (center_x, center_y).
    """
    center_x = (box[0] + box[2]) / 2
    center_y = (box[1] + box[3]) / 2
    return np.array([center_x, center_y])

# %%
def speed_interval(speed,thresh):
    if speed==99999:
        return 0
    elif speed>thresh:
        return 2
    else:
        return 1

# %%
def determine_movement_state(relative_displacement, bounding_box_width, bounding_box_height):
    if relative_displacement > 0.00045 * max(bounding_box_width, bounding_box_height):
        return 2  # Moving
    else:
        return 1  # Stopped

# %% [markdown]
# ## $Both \space Classes  \space Detection$: *``Absolute threshold vlaue``*

# %%
# Step 1: Read the video using a VideoCapture / Video_generator
# Step 2: Detection with supervised annotations
# Step 3: Identify Moving/Stopping objects

#  |
#  | 
#  |--->  Tracker required
#  |  |
#  |  -->  ByteTrack
#  |
#  |--->  Process Current/Previous Frames
class_names = ['Processing..', 'Stopped', 'Moving']

tracker = sv.ByteTrack(frame_rate=video_info.fps)
# Colors for each use case: Processing, Moving, Stopping
colors = sv.ColorPalette.from_hex(['#FFDBAC', '#E87A5C', '#B6E696'])
black = sv.Color.BLACK

# Video Capture - Real-Time (webcam)
cap = cv2.VideoCapture(SOURCE_VIDEO_PATH)

# Video Writer - Save results to a file
fourcc = cv2.VideoWriter_fourcc(*'MP4V')
out = cv2.VideoWriter('Both_classes_Absolute.mp4', fourcc, 25, (1920, 1080))

# Verify if the video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

threshold_speed = 10  # Speed threshold value
d = 0                   # Frame counter between the current and previous detections
step = 10               # Frame step between the previous state and the current state for speed calculation
first_attempt = True    # Indicates the first time when both old and current states are available
k = 0                   # State variable: changes at the first detection

# Annotators
trace_annotator = sv.TraceAnnotator(trace_length=70, thickness=2)
label_annotator = sv.LabelAnnotator(color = colors, text_color = black, text_position = sv.Position.TOP_LEFT, text_scale = 0.7)
color_annotator = sv.ColorAnnotator(color=colors, opacity=0.2)
ellipse_annotator = sv.EllipseAnnotator(color=colors, thickness=4)
actl_D = {}

while cap.isOpened():
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret:
        result = model(frame, classes=[0])[0]
        d += 1

        # Process only when there are detections
        if len(result[0]) > 0:

            detections = sv.Detections.from_ultralytics(result)
            detections = tracker.update_with_detections(detections)

            annotated_frame = trace_annotator.annotate(
                scene=frame.copy(),
                detections=detections
            )

            # Initialize speed to zero at the first detection
            if k == 0:
                speed_D = {detections.tracker_id[i]: 0 for i in range(len(detections.tracker_id))}
                k = 1

            if d == step:  # When the current and previous frame distances equal the step

                # Previous results 
                # Skip the first case: just for more processing purposes
                if first_attempt:
                    detections_pf = detections
                    first_attempt = False

                else:  # Apply the model on the previous frame

                    prvs_D = {detections_pf.tracker_id[i]: get_bbox_center(detections_pf.xyxy[i]) for i in range(len(detections_pf.tracker_id))}
                    actl_D = {detections.tracker_id[i]: get_bbox_center(detections.xyxy[i]) for i in range(len(detections.tracker_id))}
                    speed_D = {}

                    # Iterate over the keys in actl_D
                    for key in actl_D:
                        if key in prvs_D:
                            # Calculate the norm for common keys
                            speed_D[key] = np.linalg.norm(actl_D[key] - prvs_D[key])
                        else:
                            # Assign zero for unique keys
                            speed_D[key] = 0

                    # Update previous detections
                    detections_pf = detections
                d = 0

            # Correct and filter detection classes

            # Objects in the current frame but not in the previous frame are marked as "Processing"
            for key in list(set(detections.tracker_id.tolist()) - set(list(actl_D.keys()))):
                speed_D[key] = 99999

            if not first_attempt:
                new_classes = np.array([speed_interval(speed_D[key], threshold_speed) for key in detections.tracker_id])
                detections.class_id = new_classes

            # Annotate the frame
            labels = [
                f"ID: {tracker_id}, {class_names[class_id]}, Absolute speed: {np.round(speed_D[tracker_id], 3)} "
                for _, _, confidence, class_id, tracker_id, _,
                in detections
            ]
            annotated_frame = label_annotator.annotate(
                scene=annotated_frame,
                labels=labels,
                detections=detections
            )
            annotated_frame = color_annotator.annotate(
                scene=annotated_frame.copy(),
                detections=detections
            )
            frame = ellipse_annotator.annotate(
                scene=annotated_frame,
                detections=detections
            )

        out.write(frame)  
        cv2.imshow('window', cv2.resize(frame, (920, 560)))
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640
3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 99.8ms
# Speed: 0.0ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 104.3ms
# Speed: 0.0ms preprocess, 104.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 104.9ms
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 94.1ms
# Speed: 3.0ms preprocess, 94.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 99.5ms
# Speed: 3.0ms preprocess, 99.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 100.2ms
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 108.9ms
# Speed: 0.0ms preprocess, 108.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 108.8ms
# Speed: 0.0ms preprocess, 108.8ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 105.1ms
# Speed: 2.0ms preprocess, 105.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 105.1ms
# Speed: 5.0ms preprocess, 105.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 107.0ms
# Speed: 0.0ms preprocess, 107.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 105.3ms
# Speed: 0.0ms preprocess, 105.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 102.1ms
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 101.3ms
# Speed: 4.6ms preprocess, 101.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 104.7ms
# Speed: 0.0ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 99.2ms
# Speed: 3.0ms preprocess, 99.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 100.3ms
# Speed: 5.5ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 111.8ms
# Speed: 0.0ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 106.0ms
# Speed: 0.0ms preprocess, 106.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 111.3ms
# Speed: 0.0ms preprocess, 111.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 89.8ms
# Speed: 5.0ms preprocess, 89.8ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 99.9ms
# Speed: 3.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 110.1ms
# Speed: 0.0ms preprocess, 110.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 109.3ms
# Speed: 0.0ms preprocess, 109.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 94.7ms
# Speed: 0.0ms preprocess, 94.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 100.0ms
# Speed: 0.0ms preprocess, 100.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 100.5ms
# Speed: 0.0ms preprocess, 100.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 95.0ms
# Speed: 5.0ms preprocess, 95.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 99.9ms
# Speed: 0.0ms preprocess, 99.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 98.9ms
# Speed: 0.0ms preprocess, 98.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 108.1ms
# Speed: 0.0ms preprocess, 108.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 109.8ms
# Speed: 0.0ms preprocess, 109.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 110.0ms
# Speed: 0.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 99.1ms
# Speed: 5.2ms preprocess, 99.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 90.0ms
# Speed: 0.0ms preprocess, 90.0ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 104.8ms
# Speed: 0.0ms preprocess, 104.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 115.0ms
# Speed: 0.0ms preprocess, 115.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 118.9ms
# Speed: 0.0ms preprocess, 118.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 115.4ms
# Speed: 0.0ms preprocess, 115.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 114.7ms
# Speed: 0.0ms preprocess, 114.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 109.6ms
# Speed: 0.0ms preprocess, 109.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 100.2ms
# Speed: 8.1ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 100.0ms
# Speed: 7.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 96.3ms
# Speed: 3.0ms preprocess, 96.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 107.8ms
# Speed: 0.0ms preprocess, 107.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 97.1ms
# Speed: 2.0ms preprocess, 97.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 95.9ms
# Speed: 6.0ms preprocess, 95.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 105.7ms
# Speed: 3.0ms preprocess, 105.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 123.3ms
# Speed: 0.0ms preprocess, 123.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 116.4ms
# Speed: 4.0ms preprocess, 116.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 116.0ms
# Speed: 3.0ms preprocess, 116.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 90.2ms
# Speed: 9.7ms preprocess, 90.2ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## $Both \space Classes  \space Detection$: *``Relative threshold value``*

# %%
# Step 1: Read the video using a VideoCapture / Video_generator
# Step 2: Detection with supervised annotations
# Step 3: Identify moving/stopping objects

#  |
#  | 
#  |--->  Tracker required
#  |  |
#  |  -->  ByteTrack
#  |
#  |--->  Process current/previous frames

class_names = ['Processing..', 'Stopped', 'Moving']

tracker = sv.ByteTrack(frame_rate=video_info.fps)

# Colors for each use case: Processing, Moving, Stop
colors = sv.ColorPalette.from_hex(['#FFDBAC', '#E87A5C', '#B6E696'])

black = sv.Color.BLACK

# Video Reading - Real-time (webcam)
cap = cv2.VideoCapture(SOURCE_VIDEO_PATH)

# Video Saver / Video Writer - results()
fourcc = cv2.VideoWriter_fourcc(*'MP4V')
out = cv2.VideoWriter('Both_classes_Relative.mp4', fourcc, 25, (1920, 1080))

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

d = 0                   # Counter: Computes the number of frames between the current and previous detections
step = 10               # Step between the previous state and the current state for speed calculation: number of frames
first_attempt = True    # First attempt: Initial state calculation after getting the first 8 frames (based on step)
k = 0                   # State variable: Changes after the first detection

# Annotators
trace_annotator = sv.TraceAnnotator(trace_length = 70, thickness = 2)
label_annotator = sv.LabelAnnotator(color = colors, text_color = black, text_position = sv.Position.TOP_LEFT, text_scale = 0.7)
color_annotator = sv.ColorAnnotator(color = colors, opacity = 0.2)
ellipse_annotator = sv.EllipseAnnotator(color = colors, thickness = 4)
actl_D = {}

while cap.isOpened():
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret:
        result = model(frame, classes = [0])[0]
        d += 1
        
        # Processing only when there is detection
        if len(result[0]) > 0:
            detections = sv.Detections.from_ultralytics(result)
            detections = tracker.update_with_detections(detections)
            detections = smoother.update_with_detections(detections)
            
            annotated_frame = trace_annotator.annotate(
                scene = frame.copy(),
                detections = detections)

            # Initialization of the speed at zero only in the first detection
            if k == 0:
                speed_D = {detections.tracker_id[i]: 0 for i in range(len(detections.tracker_id))}
                k = 1

            if d == step:  # When current-previous state distance equals the step
                # Previous results 
                # Skip the first case: just for more processing purposes
                if first_attempt:
                    detections_pf = detections
                    first_attempt = False
                else:  # Apply the model on the previous frame
                    prvs_D = {detections_pf.tracker_id[i]: get_bbox_center(detections_pf.xyxy[i]) for i in range(len(detections_pf.tracker_id))}
                    actl_D = {detections.tracker_id[i]: [detections.xyxy[i][2] - detections.xyxy[i][0], (detections.xyxy[i][3] - detections.xyxy[i][1]), get_bbox_center(detections.xyxy[i])] for i in range(len(detections.tracker_id))}
                    speed_D = {}
                    
                    # Iterate over the keys in actl_D
                    for key in actl_D:
                        if key in prvs_D:
                            # Calculate the norm for common keys
                            width = actl_D[key][0]
                            height = actl_D[key][1]
                            relative_displacement = np.linalg.norm(actl_D[key][2] - prvs_D[key]) / np.max([width, height])

                            speed_D[key] = [relative_displacement, determine_movement_state(relative_displacement, width, height)]
                        else:
                            # Assign zero for unique keys
                            speed_D[key] = [99999, 0]

                    # Updating previous detections
                    detections_pf = detections
                d = 0

             
            # For new objects appearing in the frame, objects in the current frame and not in the previous. 
            # In this case, create a new class: under processing class 
            for key in list(set(detections.tracker_id.tolist()) - set(list(actl_D.keys()))):
                speed_D[key] = [99999, 0]

            if not first_attempt:
                new_classes = np.array([speed_D[key][1] for key in detections.tracker_id])
                detections.class_id = new_classes
        
            # Annotation  
            labels = [
                f"ID: {tracker_id}, {class_names[class_id]}, Relative speed: {np.round(speed_D[tracker_id][0], 3)}"
                for _, _, confidence, class_id, tracker_id, _,
                in detections
            ]
            annotated_frame = label_annotator.annotate(
                scene = annotated_frame.copy(),
                labels = labels,
                detections = detections
            )
            annotated_frame = color_annotator.annotate(
                scene = annotated_frame.copy(),
                detections = detections
            )
            frame = ellipse_annotator.annotate(
                scene = annotated_frame.copy(),
                detections = detections
            )

        out.write(frame)  
        cv2.imshow('window', cv2.resize(frame, (920, 560)))
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 35 persons, 318.2ms
# Speed: 1.8ms preprocess, 318.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 99.9ms
# Speed: 0.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 89.7ms
# Speed: 0.0ms preprocess, 89.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 89.3ms
# Speed: 0.0ms preprocess, 89.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 80.4ms
# Speed: 1.1ms preprocess, 80.4ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 73.9ms
# Speed: 3.5ms preprocess, 73.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 85.5ms
# Speed: 0.0ms preprocess, 85.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons,
0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 93.7ms
# Speed: 4.0ms preprocess, 93.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 90.5ms
# Speed: 3.0ms preprocess, 90.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 93.7ms
# Speed: 3.0ms preprocess, 93.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 90.0ms
# Speed: 3.0ms preprocess, 90.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 95.1ms
# Speed: 2.0ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 91.0ms
# Speed: 3.0ms preprocess, 91.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 93.9ms
# Speed: 2.0ms preprocess, 93.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 92.9ms
# Speed: 2.0ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 90.6ms
# Speed: 2.0ms preprocess, 90.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 90.8ms
# Speed: 3.1ms preprocess, 90.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 91.3ms
# Speed: 2.0ms preprocess, 91.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 90.6ms
# Speed: 2.0ms preprocess, 90.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 94.7ms
# Speed: 3.5ms preprocess, 94.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 91.7ms
# Speed: 3.0ms preprocess, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 96.7ms
# Speed: 1.0ms preprocess, 96.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 91.7ms
# Speed: 3.0ms preprocess, 91.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 91.3ms
# Speed: 3.0ms preprocess, 91.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 95.1ms
# Speed: 2.0ms preprocess, 95.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## $ Stopped$ ``Only``  $\space Persons  \space  Detection$

# %%
# Step 1: Read the video using a Streamlit generator
# Step 2: Detection with supervised annotations
# Step 3: Identify moving/stopping objects

#  |
#  | 
#  |--->  Tracker required
#  |  |
#  |  -->  ByteTrack
#  |
#  |--->  Process current/previous frames

class_names = ['Processing..', 'Stopped', 'Moving']

tracker = sv.ByteTrack(frame_rate=video_info.fps)

# Colors for each use case: Processing, Moving, Stop
colors = sv.ColorPalette.from_hex(['#FFDBAC', '#E87A5C', '#B6E696'])

black = sv.Color.BLACK
ROBOFLOW=sv.Color.ROBOFLOW

# Video Reading - Real-time (webcam)
cap = cv2.VideoCapture(SOURCE_VIDEO_PATH)

# Video Saver / Video Writer - results()
fourcc = cv2.VideoWriter_fourcc(*'MP4V')
out = cv2.VideoWriter('Stopped_Olny.mp4', fourcc, 25, (1920, 1080))

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

d = 0  # Counter: Computes the number of frames between the current and previous detections
step = 10  # Step between the previous state and the current state for speed calculation: number of frames
first_attempt = True  # First attempt: Initial state calculation after getting the first 8 frames (based on step)
k = 0  # State variable: Changes after the first detection

# Annotators
trace_annotator = sv.TraceAnnotator(color=ROBOFLOW,trace_length = 70, thickness = 3)
label_annotator = sv.LabelAnnotator(color = colors, text_color = black, text_position = sv.Position.TOP_LEFT, text_scale = 0.7)
color_annotator = sv.ColorAnnotator(color = colors, opacity = 0.3)
ellipse_annotator = sv.EllipseAnnotator(color = colors, thickness = 4)
actl_D = {}

while cap.isOpened():
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret:
        result = model(frame, classes = [0])[0]
        d += 1
        
        # Processing only when there is detection
        if len(result[0]) > 0:
            detections = sv.Detections.from_ultralytics(result)
            detections = tracker.update_with_detections(detections)
            detections = smoother.update_with_detections(detections)
            
            

            # Initialization of the speed at zero only in the first detection
            if k == 0:
                speed_D = {detections.tracker_id[i]: 0 for i in range(len(detections.tracker_id))}
                k = 1

            if d == step:  # When current-previous state distance equals the step
                # Previous results 
                # Skip the first case: just for more processing purposes
                if first_attempt:
                    detections_pf = detections
                    first_attempt = False
                else:  # Apply the model on the previous frame
                    prvs_D = {detections_pf.tracker_id[i]: get_bbox_center(detections_pf.xyxy[i]) for i in range(len(detections_pf.tracker_id))}
                    actl_D = {detections.tracker_id[i]: [detections.xyxy[i][2] - detections.xyxy[i][0], (detections.xyxy[i][3] - detections.xyxy[i][1]), get_bbox_center(detections.xyxy[i])] for i in range(len(detections.tracker_id))}
                    speed_D = {}
                    
                    # Iterate over the keys in actl_D
                    for key in actl_D:
                        if key in prvs_D:
                            # Calculate the norm for common keys
                            width = actl_D[key][0]
                            height = actl_D[key][1]
                            relative_displacement = np.linalg.norm(actl_D[key][2] - prvs_D[key]) / np.max([width, height])

                            speed_D[key] = [relative_displacement, determine_movement_state(relative_displacement, width, height)]
                        else:
                            # Assign zero for unique keys
                            speed_D[key] = [99999, 0]

                    # Updating previous detections
                    detections_pf = detections
                d = 0




            
            # For new objects appearing in the frame, objects in the current frame and not in the previous. 
            # In this case, create a new class: under processing class 
            for key in list(set(detections.tracker_id.tolist()) - set(list(actl_D.keys()))):
                speed_D[key] = [99999, 0]

            if not first_attempt:
                new_classes = np.array([speed_D[key][1] for key in detections.tracker_id])
                detections.class_id = new_classes
            

            
            # Filtering 
            selected_classes = [0, 1] 
            detections=detections[np.isin(detections.class_id, selected_classes)]

            # Annotation 
            annotated_frame = trace_annotator.annotate(
                scene = frame.copy(),
                detections = detections)
              
            labels = [
                f"ID: {tracker_id}, {class_names[class_id]}, Relative speed: {np.round(speed_D[tracker_id][0], 3)}"
                for _, _, confidence, class_id, tracker_id, _,
                in detections
            ]
            annotated_frame = label_annotator.annotate(
                scene = annotated_frame.copy(),
                labels = labels,
                detections = detections
            )
            annotated_frame = color_annotator.annotate(
                scene = annotated_frame.copy(),
                detections = detections
            )
            frame = ellipse_annotator.annotate(
                scene = annotated_frame.copy(),
                detections = detections
            )

        out.write(frame)  
        cv2.imshow('window', cv2.resize(frame, (920, 560)))
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 35 persons, 386.3ms
# Speed: 14.2ms preprocess, 386.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 101.9ms
# Speed: 4.0ms preprocess, 101.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 85.1ms
# Speed: 2.9ms preprocess, 85.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 99.8ms
# Speed: 0.0ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 96.8ms
# Speed: 0.0ms preprocess, 96.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 85.9ms
# Speed: 0.0ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 82.5ms
# Speed: 0.0ms preprocess, 82.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 84.7ms
# Speed: 0.0ms preprocess, 84.7ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 99.8ms
# Speed: 0.0ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 101.6ms
# Speed: 0.0ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 99.2ms
# Speed: 0.0ms preprocess, 99.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 84.6ms
# Speed: 0.0ms preprocess, 84.6ms inference, 16.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 98.1ms
# Speed: 0.0ms preprocess, 98.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 101.9ms
# Speed: 0.0ms preprocess, 101.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 99.4ms
# Speed: 0.0ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 90.0ms
# Speed: 5.7ms preprocess, 90.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 97.0ms
# Speed: 0.0ms preprocess, 97.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 97.6ms
# Speed: 0.0ms preprocess, 97.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 94.2ms
# Speed: 2.1ms preprocess, 94.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 92.9ms
# Speed: 4.5ms preprocess, 92.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 94.4ms
# Speed: 3.0ms preprocess, 94.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 91.6ms
# Speed: 2.2ms preprocess, 91.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 94.7ms
# Speed: 3.0ms preprocess, 94.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 91.7ms
# Speed: 3.0ms preprocess, 91.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 94.2ms
# Speed: 3.0ms preprocess, 94.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 93.7ms
# Speed: 5.0ms preprocess, 93.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 92.5ms
# Speed: 2.0ms preprocess, 92.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 76.8ms
# Speed: 2.0ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 91.4ms
# Speed: 2.0ms preprocess, 91.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 93.3ms
# Speed: 2.0ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 91.1ms
# Speed: 2.0ms preprocess, 91.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 93.9ms
# Speed: 3.0ms preprocess, 93.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 91.8ms
# Speed: 2.0ms preprocess, 91.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 91.9ms
# Speed: 3.0ms preprocess, 91.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 94.3ms
# Speed: 3.0ms preprocess, 94.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 90.3ms
# Speed: 2.0ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 94.3ms
# Speed: 2.0ms preprocess, 94.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 94.4ms
# Speed: 2.0ms preprocess, 94.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 96.0ms
# Speed: 2.0ms preprocess, 96.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 97.0ms
# Speed: 0.0ms preprocess, 97.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 92.2ms
# Speed: 2.0ms preprocess, 92.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 91.8ms
# Speed: 2.0ms preprocess, 91.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 92.1ms
# Speed: 2.0ms preprocess, 92.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 93.1ms
# Speed: 3.0ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 92.5ms
# Speed: 3.0ms preprocess, 92.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 89.8ms
# Speed: 3.0ms preprocess, 89.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons,
ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 99.5ms
# Speed: 3.0ms preprocess, 99.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 95.6ms
# Speed: 2.0ms preprocess, 95.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 98.9ms
# Speed: 2.0ms preprocess, 98.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 96.4ms
# Speed: 3.0ms preprocess, 96.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 108.7ms
# Speed: 0.0ms preprocess, 108.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 92.7ms
# Speed: 2.0ms preprocess, 92.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 84.5ms
# Speed: 3.0ms preprocess, 84.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 87.7ms
# Speed: 2.0ms preprocess, 87.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 103.8ms
# Speed: 2.0ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 116.1ms
# Speed: 3.1ms preprocess, 116.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 113.9ms
# Speed: 0.0ms preprocess, 113.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 104.9ms
# Speed: 2.0ms preprocess, 104.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 110.4ms
# Speed: 0.0ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 97.8ms
# Speed: 0.0ms preprocess, 97.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 104.2ms
# Speed: 3.0ms preprocess, 104.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 100.2ms
# Speed: 2.0ms preprocess, 100.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 101.4ms
# Speed: 0.0ms preprocess, 101.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 93.3ms
# Speed: 1.1ms preprocess, 93.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 92.4ms
# Speed: 3.0ms preprocess, 92.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 97.1ms
# Speed: 3.0ms preprocess, 97.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 87.8ms
# Speed: 3.0ms preprocess, 87.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 99.8ms
# Speed: 2.0ms preprocess, 99.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 105.6ms
# Speed: 2.0ms preprocess, 105.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 103.1ms
# Speed: 2.0ms preprocess, 103.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 105.9ms
# Speed: 0.0ms preprocess, 105.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 93.2ms
# Speed: 0.0ms preprocess, 93.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 104.1ms
# Speed: 0.0ms preprocess, 104.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 90.6ms
# Speed: 6.3ms preprocess, 90.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 101.1ms
# Speed: 2.0ms preprocess, 101.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 97.1ms
# Speed: 2.0ms preprocess, 97.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 94.4ms
# Speed: 2.0ms preprocess, 94.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 77.8ms
# Speed: 15.7ms preprocess, 77.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 106.5ms
# Speed: 0.0ms preprocess, 106.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 82.8ms
# Speed: 2.0ms preprocess, 82.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 94.9ms
# Speed: 3.0ms preprocess, 94.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 93.1ms
# Speed: 2.0ms preprocess, 93.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## $Moving$ ``Only``$\space Persons \space Detection$

# %%
# Step 1: Read the video using a VideoCapture / Video_generator
# Step 2: Detection with supervised annotations
# Step 3: Identify moving/stopping objects

#  |
#  | 
#  |--->  Tracker required
#  |  |
#  |  -->  ByteTrack
#  |
#  |--->  Process current/previous frames

class_names = ['Processing..', 'Stopped', 'Moving']

tracker = sv.ByteTrack(frame_rate=video_info.fps)

# Colors for each use case: Processing, Moving, Stop
colors = sv.ColorPalette.from_hex(['#FFDBAC', '#E87A5C', '#B6E696'])

black = sv.Color.BLACK
ROBOFLOW=sv.Color.ROBOFLOW
# Video Reading - Real-time (webcam)
cap = cv2.VideoCapture(SOURCE_VIDEO_PATH)

# Video Saver / Video Writer - results()
fourcc = cv2.VideoWriter_fourcc(*'MP4V')
out = cv2.VideoWriter('Moving_only.mp4', fourcc, 25, (1920, 1080))

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

d = 0                 # Counter: Computes the number of frames between the current and previous detections
step = 10             # Step between the previous state and the current state for speed calculation: number of frames
first_attempt = True  # First attempt: Initial state calculation after getting the first 8 frames (based on step)
k = 0                 # State variable: Changes after the first detection

# Annotators
trace_annotator = sv.TraceAnnotator(color=ROBOFLOW,trace_length = 70, thickness = 3)
label_annotator = sv.LabelAnnotator(color = colors, text_color = black, text_position = sv.Position.TOP_LEFT, text_scale = 0.7)
color_annotator = sv.ColorAnnotator(color = colors, opacity = 0.3)
ellipse_annotator = sv.EllipseAnnotator(color = colors, thickness = 4)
actl_D = {}

while cap.isOpened():
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret:
        result = model(frame, classes = [0])[0]
        d += 1
        
        # Processing only when there is detection
        if len(result[0]) > 0:
            detections = sv.Detections.from_ultralytics(result)
            detections = tracker.update_with_detections(detections)
            detections = smoother.update_with_detections(detections)
            


            # Initialization of the speed at zero only in the first detection
            if k == 0:
                speed_D = {detections.tracker_id[i]: 0 for i in range(len(detections.tracker_id))}
                k = 1

            if d == step:  # When current-previous state distance equals the step
                # Previous results 
                # Skip the first case: just for more processing purposes
                if first_attempt:
                    detections_pf = detections
                    first_attempt = False
                else:  # Apply the model on the previous frame
                    prvs_D = {detections_pf.tracker_id[i]: get_bbox_center(detections_pf.xyxy[i]) for i in range(len(detections_pf.tracker_id))}
                    actl_D = {detections.tracker_id[i]: [detections.xyxy[i][2] - detections.xyxy[i][0], (detections.xyxy[i][3] - detections.xyxy[i][1]), get_bbox_center(detections.xyxy[i])] for i in range(len(detections.tracker_id))}
                    speed_D = {}
                    
                    # Iterate over the keys in actl_D
                    for key in actl_D:
                        if key in prvs_D:
                            # Calculate the norm for common keys
                            width = actl_D[key][0]
                            height = actl_D[key][1]
                            relative_displacement = np.linalg.norm(actl_D[key][2] - prvs_D[key]) / np.max([width, height])

                            speed_D[key] = [relative_displacement, determine_movement_state(relative_displacement, width, height)]
                        else:
                            # Assign zero for unique keys
                            speed_D[key] = [99999, 0]

                    # Updating previous detections
                    detections_pf = detections
                d = 0




            
            # For new objects appearing in the frame, objects in the current frame and not in the previous. 
            # In this case, create a new class: under processing class 
            for key in list(set(detections.tracker_id.tolist()) - set(list(actl_D.keys()))):
                speed_D[key] = [99999, 0]

            if not first_attempt:
                new_classes = np.array([speed_D[key][1] for key in detections.tracker_id])
                detections.class_id = new_classes
            

            
            # Filtering 
            selected_classes = [0, 2] 
            detections=detections[np.isin(detections.class_id, selected_classes)]


            # Annotation   
            annotated_frame = trace_annotator.annotate(
                scene = frame.copy(),
                detections = detections)
            
            labels = [
                f"ID: {tracker_id}, {class_names[class_id]}, Relative speed: {np.round(speed_D[tracker_id][0], 3)}"
                for _, _, confidence, class_id, tracker_id, _,
                in detections
            ]
            annotated_frame = label_annotator.annotate(
                scene = annotated_frame.copy(),
                labels = labels,
                detections = detections
            )
            annotated_frame = color_annotator.annotate(
                scene = annotated_frame.copy(),
                detections = detections
            )
            frame = ellipse_annotator.annotate(
                scene = annotated_frame.copy(),
                detections = detections
            )

        out.write(frame)  
        cv2.imshow('window', cv2.resize(frame, (920, 560)))
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 35 persons, 404.6ms
# Speed: 4.8ms preprocess, 404.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 103.9ms
# Speed: 2.8ms preprocess, 103.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 83.3ms
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 83.0ms
# Speed: 0.0ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 88.7ms
# Speed: 3.0ms preprocess, 88.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 87.3ms
# Speed: 3.0ms preprocess, 87.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 88.4ms
# Speed: 2.0ms preprocess, 88.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 82.2ms
# Speed: 0.0ms preprocess, 82.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 66.8ms
# Speed: 0.0ms preprocess, 66.8ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 81.2ms
# Speed: 0.0ms preprocess, 81.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 81.2ms
# Speed: 0.0ms preprocess, 81.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 83.1ms
# Speed: 0.0ms preprocess, 83.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 80.9ms
# Speed: 0.0ms preprocess, 80.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 83.8ms
# Speed: 0.0ms preprocess, 83.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 88.7ms
# Speed: 2.0ms preprocess, 88.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 82.0ms
# Speed: 0.0ms preprocess, 82.0ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 88.7ms
# Speed: 2.0ms preprocess, 88.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 93.4ms
# Speed: 0.0ms preprocess, 93.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 83.0ms
# Speed: 0.0ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 90