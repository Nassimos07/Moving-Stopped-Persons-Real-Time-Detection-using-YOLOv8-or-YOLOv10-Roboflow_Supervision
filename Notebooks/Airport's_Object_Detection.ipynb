# %% [markdown]
# #  Airport's Object Detection Using ``YOLOV8`` & ``Roboflow Supervision``
#
# ---
#
# ![aerport.png](data:image/png;base64,...)
#
# ---
#
#
#
#
# <a align="">
#   <img width="9000"src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png">
# </a>
#
# <a align="center">
#   <img width="9000" src="https://camo.githubusercontent.">
# </a>
# <div align="center">
#   <a href="https://github.com/ultralytics/ultralytics">
#     <img src="https://github.com/ultralytics/hub/actions/workflows/ci.yaml/badge.svg" alt="CI CPU"></a>
#   <a href="">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
# ---

# %% [markdown]
# # Setup

# %% [markdown]
# Install `ultralytics` to Download, Train, Test, and Export Object detection models.
#
# <a align="center">
#   <img width="200" src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png">
# </a>

# %%
# %pip install ultralytics  # install
from IPython import display
display.clear_output()

# %% [markdown]
# Install `roboflow` for datasets downloading

# %%
# %pip install roboflow
display.clear_output()

# %%
import os
import shutil
import numpy as np
import yaml
from roboflow import Roboflow
from ultralytics import YOLO, checks, hub
checks()  # checks
# Out:
# Ultralytics YOLOv8.0.188 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/107.7 GB disk)

# %% [markdown]
# ## Objects Detection

# %% [markdown]
# ## Install Supervision
#
# <a align="center">
#   <img width ="300" src="https://camo.githubusercontent.">
# </a>

# %%
# !pip install supervision==0.1.0
display.clear_output()

# %% [markdown]
# ## Install ByteTrack

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %cd {HOME}
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd {HOME}/ByteTrack

# workaround related to https://github.com/roboflow/notebooks/issues/80
# !sed -i 's/onnx==1.8.1/onnx==1.9.0/g' requirements.txt

# !pip3 install -q -r requirements.txt
# !python3 setup.py -q develop
# !pip install -q cython_bbox
# !pip install -q onemetric
# workaround related to https://github.com/roboflow/notebooks/issues/112
# !pip install -q loguru lap

display.clear_output()

# %%
# !pip3 install thop
display.clear_output()

# %%
import sys
sys.path.append(f"{HOME}/ByteTrack")
import yolox
print("yolox.__version__:", yolox.__version__)
# Out:
# yolox.__version__: 0.1.0

# %%
from yolox.tracker.byte_tracker import BYTETracker, STrack
from onemetric.cv.utils.iou import box_iou_batch
from dataclasses import dataclass


@dataclass(frozen=True)
class BYTETrackerArgs:
    track_thresh: float = 0.25
    track_buffer: int = 30
    match_thresh: float = 0.8
    aspect_ratio_thresh: float = 3.0
    min_box_area: float = 1.0
    mot20: bool = False

# %%
from supervision.draw.color import ColorPalette
from supervision.geometry.dataclasses import Point
from supervision.video.dataclasses import VideoInfo
from supervision.video.source import get_video_frames_generator
from supervision.video.sink import VideoSink
from supervision.notebook.utils import show_frame_in_notebook
from supervision.tools.detections import Detections, BoxAnnotator
from supervision.tools.line_counter import LineCounter, LineCounterAnnotator

# %% [markdown]
# ## Tracking utils

# %%
from typing import List

import numpy as np


# converts Detections into format that can be consumed by match_detections_with_tracks function
def detections2boxes(detections: Detections) -> np.ndarray:
    return np.hstack((
        detections.xyxy,
        detections.confidence[:, np.newaxis]
    ))


# converts List[STrack] into format that can be consumed by match_detections_with_tracks function
def tracks2boxes(tracks: List[STrack]) -> np.ndarray:
    return np.array([
        track.tlbr
        for track
        in tracks
    ], dtype=float)


# matches our bounding boxes with predictions
def match_detections_with_tracks(
    detections: Detections,
    tracks: List[STrack]
) -> Detections:
    if not np.any(detections.xyxy) or len(tracks) == 0:
        return np.empty((0,))

    tracks_boxes = tracks2boxes(tracks=tracks)
    iou = box_iou_batch(tracks_boxes, detections.xyxy)
    track2detection = np.argmax(iou, axis=1)

    tracker_ids = [None] * len(detections)

    for tracker_index, detection_index in enumerate(track2detection):
        if iou[tracker_index, detection_index] != 0:
            tracker_ids[detection_index] = tracks[tracker_index].track_id

    return tracker_ids

# %% [markdown]
# # Import the model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO
model = YOLO("path\best.pt")  # load a pretrained model (recommended for training)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x.pt to yolov8x.pt...
# 100%|██████████| 131M/131M [00:11<00:00, 11.5MB/s]

# %% [markdown]
# # Tracking and detection

# %% [markdown]
# ## The Input Video: *the video that we will test it*

# %%
SOURCE_VIDEO_PATH='/content/pexels-taryn-elliott-4684101-1920x1080-25fps.mp4'   #  Change the path
VideoInfo.from_video_path(SOURCE_VIDEO_PATH)

# %% [markdown]
# ## The Output Video: *the name of the result video*

# %%
TARGET_VIDEO_PATH = f"{HOME}/Airport1-result.mp4"

# %% [markdown]
# ## Tracking & Detection

# %%
# dict maping class_id to class_name
CLASS_NAMES_DICT = model.model.names
# class_ids of interest - car, motorcycle, bus and truck
CLASS_ID = [i for i in range(3)]

# %%
CLASS_NAMES_DICT
# Out:
# {0: 'backpack', 1: 'person', 2: 'suitcase'}

# %%
from tqdm.notebook import tqdm

# create BYTETracker instance
byte_tracker = BYTETracker(BYTETrackerArgs())
# create VideoInfo instance
video_info = VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
# create frame generator
generator = get_video_frames_generator(SOURCE_VIDEO_PATH)
# create LineCounter instance
# create instance of BoxAnnotator and LineCounterAnnotator
box_annotator = BoxAnnotator(color=ColorPalette.default(), thickness=1, text_thickness=1, text_scale=1)

# open target video file

with VideoSink(TARGET_VIDEO_PATH, video_info) as sink:
    # loop over video frames
    for frame in tqdm(generator, total=video_info.total_frames):

        # model prediction on single frame and conversion to supervision Detections
        results = model(frame,conf=0.55)
        detections = Detections(
            xyxy=results[0].boxes.xyxy.cpu().numpy(),
            confidence=results[0].boxes.conf.cpu().numpy(),
            class_id=results[0].boxes.cls.cpu().numpy().astype(int)
        )
        # filtering out detections with unwanted classes
        mask = np.array([class_id in CLASS_ID for class_id in detections.class_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # tracking detections
        tracks = byte_tracker.update(
            output_results=detections2boxes(detections=detections),
            img_info=frame.shape,
            img_size=frame.shape
        )
        tracker_id = match_detections_with_tracks(detections=detections, tracks=tracks)
        detections.tracker_id = np.array(tracker_id)
        # filtering out detections without trackers
        mask = np.array([tracker_id is not None for tracker_id in detections.tracker_id], dtype=bool)
        detections.filter(mask=mask, inplace=True)
        # format custom labels
        labels = [
            f"#{tracker_id} {CLASS_NAMES_DICT[class_id]} {confidence:0.2f}"
            for _, confidence, class_id, tracker_id
            in detections
        ]
        # updating line counter
        # annotate and display frame
        frame = box_annotator.annotate(frame=frame, detections=detections, labels=labels)
        sink.write_frame(frame)
# Out:
#   0%|          | 0/349 [00:00<?, ?it/s]
# 0: 384x640 1 backpack, 5 persons, 1 suitcase, 1947.1ms
# Speed: 6.7ms preprocess, 1947.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 suitcase, 2558.0ms
# Speed: 4.5ms preprocess, 2558.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 suitcase, 2101.4ms
# Speed: 3.8ms preprocess, 2101.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 5 persons, 1 suitcase, 1351.0ms
# Speed: 4.3ms preprocess, 1351.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 5 persons, 1 suitcase, 1336.6ms
# Speed: 3.8ms preprocess, 1336.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 5 persons, 1 suitcase, 1385.2ms
# Speed: 4.0ms preprocess, 1385.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 5 persons, 1 suitcase, 1341.9ms
# Speed: 2.9ms preprocess, 1341.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 5 persons, 1 suitcase, 1344.2ms
# Speed: 3.7ms preprocess, 1344.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 4 persons, 1 suitcase, 1446.0ms
# Speed: 7.3ms preprocess, 1446.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 4 persons, 1 suitcase, 2469.1ms
# Speed: 4.7ms preprocess, 2469.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 4 persons, 1 suitcase, 1512.3ms
# Speed: 4.6ms preprocess, 1512.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 3 persons, 1 suitcase, 1335.1ms
# Speed: 3.9ms preprocess, 1335.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 4 persons, 1 suitcase, 1344.1ms
# Speed: 3.8ms preprocess, 1344.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 4 persons, 1 suitcase, 1336.5ms
# Speed: 3.5ms preprocess, 1336.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 3 persons, 1 suitcase, 1358.5ms
# Speed: 2.9ms preprocess, 1358.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backpack, 3 persons, 1 suitcase, 
3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1367.7ms
# Speed: 4.6ms preprocess, 1367.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 suitcases, 1966.0ms
# Speed: 4.5ms preprocess, 1966.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 suitcases, 2283.0ms
# Speed: 6.5ms preprocess, 2283.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1397.1ms
# Speed: 4.9ms preprocess, 1397.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1361.6ms
# Speed: 4.3ms preprocess, 1361.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1355.4ms
# Speed: 3.3ms preprocess, 1355.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1346.7ms
# Speed: 6.4ms preprocess, 1346.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1352.3ms
# Speed: 4.5ms preprocess, 1352.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1362.5ms
# Speed: 4.6ms preprocess, 1362.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1364.0ms
# Speed: 2.9ms preprocess, 1364.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 2300.2ms
# Speed: 3.0ms preprocess, 2300.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1845.2ms
# Speed: 8.9ms preprocess, 1845.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1361.3ms
# Speed: 6.2ms preprocess, 1361.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1383.7ms
# Speed: 7.4ms preprocess, 1383.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1365.5ms
# Speed: 3.7ms preprocess, 1365.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1364.7ms
# Speed: 3.1ms preprocess, 1364.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1367.0ms
# Speed: 3.9ms preprocess, 1367.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1382.7ms
# Speed: 3.6ms preprocess, 1382.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1705.6ms
# Speed: 4.3ms preprocess, 1705.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 2377.6ms
# Speed: 3.8ms preprocess, 2377.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1352.5ms
# Speed: 3.6ms preprocess, 1352.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1364.8ms
# Speed: 4.1ms preprocess, 1364.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1348.2ms
# Speed: 2.9ms preprocess, 1348.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1356.5ms
# Speed: 4.5ms preprocess, 1356.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1362.0ms
# Speed: 5.1ms preprocess, 1362.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1358.4ms
# Speed: 6.1ms preprocess, 1358.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1370.5ms
# Speed: 3.5ms preprocess, 1370.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 2329.3ms
# Speed: 3.6ms preprocess, 2329.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1815.0ms
# Speed: 3.9ms preprocess, 1815.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1362.2ms
# Speed: 2.9ms preprocess, 1362.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1355.4ms
# Speed: 5.2ms preprocess, 1355.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1363.0ms
# Speed: 3.3ms preprocess, 1363.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 suitcases, 1362.4ms
# Speed: 3.9ms preprocess, 1362.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1343.8ms
# Speed: 2.9ms preprocess, 1343.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1341.2ms
# Speed: 5.8ms preprocess, 1341.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1803.2ms
# Speed: 4.3ms preprocess, 1803.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 2361.4ms
# Speed: 3.8ms preprocess, 2361.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1389.7ms
# Speed: 3.5ms preprocess, 1389.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1365.6ms
# Speed: 3.8ms preprocess, 1365.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 suitcases, 1369.2ms
# Speed: 3.9ms preprocess, 1369.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1432.9ms
# Speed: 3.5ms preprocess, 1432.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 suitcases, 2401.3ms
# Speed: 3.4ms preprocess, 2401.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 suitcases, 1672.2ms
# Speed: 3.7ms preprocess, 1672.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 2313.6ms
# Speed: 6.9ms preprocess, 2313.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1792.5ms
# Speed: 9.4ms preprocess, 1792.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1355.2ms
# Speed: 3.9ms preprocess, 1355.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1360.9ms
# Speed: 3.6ms preprocess, 1360.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 suitcases, 1365.7ms
# Speed: 3.2ms preprocess, 1365.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 suitcase, 1369.4ms
# Speed: 3.5ms preprocess, 1369.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 suitcase, 1353.0ms
# Speed: 4.2ms preprocess, 1353.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 suitcase, 1349.8ms
# Speed: 3.3ms preprocess, 1349.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 suitcase, 1677.2ms
# Speed: 3.3ms preprocess, 1677.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
# !cp -av '/content/Airport1-result.mp4' "/content/drive/MyDrive"
# Out:
# '/content/Airport1-result.mp4' -> '/content/drive/MyDrive/Airport1-result.mp4'
